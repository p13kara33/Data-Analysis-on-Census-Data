# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import freq_graphs as fg
# import freq_tables as ft
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\\Users\\Giorgis\\Desktop\\Projects\\ADTA coursework\\partI\\Census.csv")
data.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %% [markdown]
# # Code for Region frequency graph

# %%
title = 'Number of οccurrences per region'
fg.freq_graph((9,6), 'Region', data, fg.regions, title, 30, 'right', 'freq_Reg.jpeg')
# ft.freq_dict_creator(data, 'Region', ft.regions, 'Fregions')

# %% [markdown]
# # Code for Residence Type frequency graph

# %%
title = 'Number of οccurrences per Residence Type'
fg.freq_graph((12,9), 'Residence Type', data, fg.residence_type, title, 0, 'center', 'freq_ResidT.jpeg')
# ft.freq_dict_creator(data, 'Residence Type', ft.residence_type, 'Fresidence')

# %% [markdown]
# # Code for Family Composition frequency graph

# %%
title = 'Number of οccurrences per Family Composition'
fg.freq_graph((12,9), 'Family Composition', data, fg.family_composition, title, 30, 'right', 'freq_FamComp.jpeg')
# ft.freq_dict_creator(data, 'Family Composition', ft.family_composition, 'Ffamliy_C')

# %% [markdown]
# # Code for Population Base frequency graph

# %%
figS = (9, 6)
title = 'Number of οccurrences'
picName ='freq_PopltBase.jpeg'
fg.freq_graph(figS, 'Population Base', data, fg.population_base, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Population Base', ft.population_base, 'Fpopulation_base')

# %% [markdown]
# # Code for Gender frequency graph

# %%
figS = (7.5, 7)
title = 'Number of οccurrences per Gender'
picName = 'freq_Sex.jpeg'
fg.freq_graph(figS, 'Sex', data, fg.sex, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Sex', ft.sex, 'Fgender')

# %% [markdown]
# # Code for Marital Status frequency graph

# %%
figS = (9, 6)
title = 'Number of οccurrences per Marital Status'
picName = 'freq_MaritalSt.jpeg'
fg.freq_graph(figS, 'Marital Status', data, fg.marital_status, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Marital Status', ft.marital_status, 'Fmarital_status')

# %% [markdown]
# # Code for Students or non Students frequency graph

# %%
figS = (7.5, 7)
title = 'Number of Students and No Students'
picName = 'freq_Stud.jpeg'
fg.freq_graph(figS, 'Student', data, fg.student, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Student', ft.student, 'Fstudent')

# %% [markdown]
# # Code for Country of Birth frequency graph

# %%
figS = (9, 6)
title = 'Number of οccurrences per Country of Birth'
picName = 'freq_BirthCountry.jpeg'
fg.freq_graph(figS, 'Country of Birth', data, fg.country_of_birth, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Country of Birth', ft.country_of_birth, 'Fcountry_of_birth')

# %% [markdown]
# # Code for Health statuses frequency graph

# %%
figS = (9, 6)
title = 'Number of οccurrences per state of Health'
picName = 'freq_Health.jpeg'
fg.freq_graph(figS, 'Health', data, fg.health, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Health', ft.health, 'Fhealth')

# %% [markdown]
# # Code for frequency graph in every Ethnic Group

# %%
figS = (9, 6)
title = 'Number of οccurrences per Ethnic Groupd'
picName = 'freq_EthnicGrp.jpeg'
fg.freq_graph(figS, 'Ethnic Group', data, fg.ethnic_group, title, 30, 'right', picName)
# ft.freq_dict_creator(data, 'Ethnic Group', ft.ethnic_group, 'Fethnic_grp')

# %% [markdown]
# # Code for Religion frequency graph

# %%
figS = (9, 6)
title = 'Number of οccurrences per Religion'
picName = 'freq_Religion.jpeg'
fg.freq_graph(figS, 'Religion', data, fg.religion, title, 30, 'right', picName)
# ft.freq_dict_creator(data, 'Religion', ft.religion, 'Freligion')

# %% [markdown]
# # Code for Economic Activity frequency graph

# %%
fg.freq_graph((15, 10), 'Economic Activity', data, fg.economic_activity, 'Number of οccurrences per Economic Activity', 30, 'right', 'freq_EconAct.jpeg')
# ft.freq_dict_creator(data, 'Economic Activity', ft.economic_activity, 'Feconomic_activity')

# %% [markdown]
# # Code for Occupation frequency graph

# %%
figS = (12, 8)
title = 'Number of οccurrences per Occupation'
picName = 'freq_Occupation.jpeg'
fg.freq_graph(figS, 'Occupation', data, fg.occupation, title, 30, 'right', picName)
# ft.freq_dict_creator(data, 'Occupation', ft.occupation, 'Foccupation')

# %% [markdown]
# # Code for Industry's frequency graph

# %%
figS = (15, 8)
title = 'Number of οccurrences per Industry\'s type'
picName ='freq_industry.jpeg'
fg.freq_graph(figS, "Industry", data, fg.industry, title, 30, 'right', picName)
# ft.freq_dict_creator(data, 'Industry', ft.industry, 'Findusrty')

# %% [markdown]
# # Code for Approximated social grade frequency graph

# %%
figS = (12, 9)
title = 'Number of οccurrences per Approximated Social Grade'
picName = 'freq_SocialGrd.jpeg'
fg.freq_graph(figS, 'Approximated Social Grade', data, fg.approx_social_grade, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Approximated Social Grade', ft.approx_social_grade, 'Fsocial_grade')

# %%
figS = (9, 6)
title = 'Total οccurrences in \nHours worked per week attribute'
picName = 'hw_per_week.jpeg'
fg.freq_graph(figS, 'Hours worked per week', data, fg.hw_per_week, title, 0, 'center', picName)
# ft.freq_dict_creator(data, 'Hours worked per week', ft.hw_per_week, 'Fhw_per_week')
